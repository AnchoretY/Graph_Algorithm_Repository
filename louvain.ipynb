# %%
# -*- coding: utf-8 -*-
import matplotlib.pyplot as plt
import networkx as nx
import community as community_louvain
from graph_toolbox.common import *

# %% [markdown]
# ### 安装louvain包

# %% [markdown]
# &emsp;&emsp;上面的community包就是python_louvian包，与其名称不同，安装时候需要重点注意。

# %% [markdown]
#     `pip install python_louvain`

# %% [markdown]
# ## 使用karate_club图进行louvain社区聚类

# %% [markdown]
# #### louvain社区聚类

# %%
G = nx.karate_club_graph()

# %%
nx.draw_networkx(G)

# %%
partition = community_louvain.best_partition(G)

# %%
view_result(G,partition)
# Out:
# Network has 4 comunitys!
# The info of comunitys are as fllow:
# Comunitys 1 is: [0, 1, 2, 3, 7, 11, 12, 13, 17, 19, 21]
# Comunitys 2 is: [4, 5, 6, 10, 16]
# Comunitys 3 is: [8, 9, 14, 15, 18, 20, 22, 26, 29, 30, 32, 33]
# Comunitys 4 is: [23, 24, 25, 27, 28, 31]

# %% [markdown]
# #### LPA 社区聚类

# %%
partition_lpa = nx.algorithms.community.asyn_lpa_communities(G)

# %%
view_result2(G,partition_lpa)
# Out:
# Network has 5 comunitys!
# The info of comunitys are as fllow:
# Comunitys 0 is: {0, 1, 2, 3, 7, 9, 11, 12, 13, 17, 19, 21}
# Comunitys 1 is: {10, 4}
# Comunitys 2 is: {16, 5, 6}
# Comunitys 3 is: {32, 33, 8, 14, 15, 18, 20, 22, 23, 26, 27, 29, 30}
# Comunitys 4 is: {24, 25, 28, 31}
